# %% [markdown]
# # Research Participant

# %% [markdown]
# Firstly, thank you for participating in this research project. Below is a description of what is required of you as a participant in this research project.
#
# If you have any questions or issues with the course, please do not hesitate to email me at Hannah Nairn at 2002964@uad.ac.uk

# %% [markdown]
# ## What does a Research Participant Do?

# %% [markdown]
# ### 1. Complete the Online Course

# %% [markdown]
# You will find all the course materials in folders that you can view from the lefthand side panel. It is recommended to complete the course in order of the folders and notebooks in each one, respectively, as the materials will build on previous notebooks and sections.
# A more in-depth introduction to the course is in the following notebook.

# %% [markdown]
# ### 2. Complete the Microsoft Form Questionnaire

# %% [markdown]
# This questionnaire is comprised of four questions, asking you about your learning experience. All questionnaire responses will remain anonymous.

# %% [markdown]
# Scan the below QR code or follow this link to complete the questionnaire.
# https://forms.office.com/r/rZcGHarDg9

# %% [markdown]
# ![QRCode for Interactive Introductory Python Questionnaire.png](attachment:859b16ae-6787-4950-bb23-e3b93c148b36.png)

# %% [markdown]
# ### 3. Complete the Microsoft Form Test

# %% [markdown]
# This test will consist of 18 multiple choice questions on the topics covered in the learning materials. All tests responses and results will remain anonymous.
#
# Scan the below QR Code or follow this link to complete the test. https://forms.office.com/r/DnxTJDkf4S

# %% [markdown]
# ![QRCode for Interactive Introductory Python End of Course Test.png](attachment:48bc3ae6-796f-4a08-897b-184e149a68c1.png)
